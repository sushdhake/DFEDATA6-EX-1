# %% [markdown]
# <a href="https://colab.research.google.com/github/sushdhake/DFEDATA6-EX-1/blob/master/Choosing_the_right_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical Machine Learning
# ### Project: Model Selection

# %% [markdown]
# # Abstract

# %% [markdown]
# # Part 1: Business and Data Understanding

# %% [markdown]
# ### Q. Define the problem domain

# %%
#How many got diagnosed with breast cancer?

# %% [markdown]
# ### Q. Identify candidate questions for your machine learning project

# %%
#Are there any null values?
#What column is my label collumn(output)?
#What columns are my feature columns(inputs)?
#Is this regression or classification?

# %% [markdown]
# ### Q. Identify a suitable dataset for your canditate question(s)

# %% [markdown]
# Go have a look at any of these websites:
#
# * https://www.kaggle.com/datasets
# * https://datasetsearch.research.google.com/
# * https://data.gov.uk/
#
# Find an interesting looking data set related to your problem domain and get a copy of it

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/cylons/master/data.csv', header=0 )
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Q. Generate a descriptive statistics report for the columns in your dataset

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# # Part 2: Data Preparation

# %% [markdown]
# ### Q. Discuss the following types of missing data and how they would be handled in reference to your dataset where applicable.
# *	Missing completely at random (MCAR)
# *	Missing at random (MAR)
# *	Missing Not at Random (MNAR)

# %%
data.info()
#since there are no null values,dont need to handle them
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # Part 3: Model Selection

# %%
x = data.iloc[:,1:11]
y = data.loc[:, ['diagnosis']]
from sklearn.model_selection import train_test_split
xtrain,xtest, ytrain,ytest = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ### Q. Use the cheat sheet below to choose the algorithm/estimator suitable for building a model to address your candidate question(s)
#
# * https://scikit-learn.org/stable/tutorial/machine_learning_map/

# %%
ytrain
# Out:
#     diagnosis
# 154         B
# 526         B
# 42          M
# 107         B
# 432         M
# ..        ...
# 185         B
# 493         B
# 2           M
# 425         B
# 217         B
#
# [455 rows x 1 columns]

# %%
ytrain['diagnosis'] = ytrain['diagnosis'].map(lambda y : 1 if y=='M' else 0)
#ytest = ytest.map(lambda y: 1 if y=='M' else 0)

# %%
ytest['diagnosis'] = ytest['diagnosis'].map(lambda y : 1 if y=='M' else 0)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
ytrain
# Out:
#      diagnosis
# 154          0
# 526          0
# 42           1
# 107          0
# 432          1
# ..         ...
# 185          0
# 493          0
# 2            1
# 425          0
# 217          0
#
# [455 rows x 1 columns]

# %%
xtrain.head()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 154         B        13.15         15.34           85.31      538.9
# 526         B        13.46         18.75           87.44      551.1
# 42          M        19.07         24.81          128.30     1104.0
# 107         B        12.36         18.54           79.01      466.7
# 432         M        20.18         19.54          133.80     1250.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 154          0.09384           0.08498         0.09293              0.03483
# 526          0.10750           0.11380         0.04201              0.03152
# 42           0.09081           0.21900         0.21070              0.09961
# 107          0.08477           0.06815         0.02643              0.01921
# 432          0.11330           0.14890         0.21330              0.12590
#
#      symmetry_mean
# 154         0.1822
# 526         0.1723
# 42          0.2310
# ...

# %%
xtrain = xtrain.iloc[:,1:]
xtest = xtest.iloc[:,1:]

# %%
model.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier()

# %%
p = model.predict(xtest)

# %% [markdown]
# # Part 4: Model Evaluation

# %% [markdown]
# ### Q. Identify which of the statistical measures below are suitable for the evaluation of your model.
#
# Classification Metrics:
# * Accuracy
# * Precision
# * Recall
# * F1 Score
#
# Regression Metrics:
#
# * Mean absolute error (MAE)
# * Root mean squared error (RMSE)
# * Relative absolute error (RAE)
# * Relative squared error (RSE)
# * Mean Zero One Error (MZOE)
# * Coefficient of determination

# %%
#mu and sigma (mean and std)
xtrain.describe().T
# Out:
#                      count        mean         std        min         25%  \
# radius_mean          455.0   14.189108    3.574944    6.98100   11.710000
# texture_mean         455.0   19.282462    4.403248    9.71000   16.025000
# perimeter_mean       455.0   92.417516   24.685475   43.79000   75.240000
# area_mean            455.0  661.282418  359.346779  143.50000  420.750000
# smoothness_mean      455.0    0.096484    0.014092    0.05263    0.086390
# compactness_mean     455.0    0.105372    0.053664    0.01938    0.066785
# concavity_mean       455.0    0.090285    0.082398    0.00000    0.029975
# concave points_mean  455.0    0.049640    0.039622    0.00000    0.020830
# symmetry_mean        455.0    0.181508    0.028022    0.10600    0.162050
#
#                            50%        75%        max
# radius_mean           13.40000   16.02500    28.1100
# texture_mean          18.82000   21.84000    39.2800
# perimeter_mean        86.91000  104.90000   188.5000
# ...

# %% [markdown]
# # Part 5: Stretch - Model Deployment

# %% [markdown]
# ### Q. Evaluate the open-source app framework for Machine Learning model deployment below in your own time.
#
# * https://streamlit.io/
